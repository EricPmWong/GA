# %% [markdown]
# # 1.03 Distributions Lab
#
# **NOTE**: Double-click on the cells that say "Type _Markdown_ and LaTeX: $\alpha^2$" to open a Markdown cell in which you can enter text without needing to put comments in code cells!

# %% [markdown]
# #### 1. Define distribution.

# %% [markdown]
# A distribution describes where the set of data falls and how often it occurs (frequency)

# %% [markdown]
# #### 2. When summarizing the distribution of a variable, what are the three aspects of distributions we want to make sure we summarize?

# %% [markdown]
# 1. An experiment is infinetely repeatable with well defined outcomes.
# 2. The sample space is the set of all possible outcomes
# 3. A random variable is any function that maps our sample space onto the real number line

# %% [markdown]
# #### 3. What is a Bernoulli random variable?

# %% [markdown]
# A varible with two possible outcomes (success and failure)

# %% [markdown]
# #### 4. What is the relationship between the Bernoulli and Binomial distributions?

# %% [markdown]
# Binomial is the sum of of independent and identially distributed Bernoulli random variables. So for example, a coin toss is a Bernoulli random variable. If I were toss a coin 10 times, the sum of success in the trials that occur will be the binomial distrbution.

# %% [markdown]
# #### 5. What is the relationship between the Binomial and Poisson distributions?

# %% [markdown]
# Binomial is based on discrete events, while Poisson is based on continuous. Binomial is also a determinable event with 2 potential outcome probabilities vs poisson which has infititely small probability trials.

# %% [markdown]
# #### 6. What is the relationship between the Exponential and Geometric distributions?

# %% [markdown]
# The geometric tracks the amount of trials it takes until one success. Whereas the exponential tracks the amount of time until one success.

# %% [markdown]
# #### 7. Let's walk through the Central Limit Theorem.
#
# a) Let's create a population of 10,000 observations from a Normal distribution with mean 500 and standard deviation 100. Save this as `population`. Before this step, however, set your seed to 45 using using `random.seed(45)`.

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(45)

population = list(np.random.normal(500, 100, 10000))

# %% [markdown]
# b) Generate 1,000 random samples of size 5 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_5`.

# %%
norm_samples_5 =[]
for x in range(0,1000):
    g = sum(np.random.choice(population, 5, False)) / 5
    norm_samples_5.append(g)
    
norm_samples_5[0:4]
# Out:
# [607.1068971463092, 422.65327219722246, 501.39356797427234, 461.14385511803476]

# %% [markdown]
# We simulated the sampling distribution of $\bar{X}$ when we took the mean of 1,000 samples from the population. This isn't exactly what the sampling distribution of $\bar{X}$ is, but it's close enough for our purposes!
#
# (In general, we'd actually take every possible sample of size 5 from our population, but that can get really complicated.)

# %% [markdown]
# c) Plot `norm_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(norm_samples_5, kde = True)

# %% [markdown]
# d) How would you describe the shape of the distribution from c)?

# %% [markdown]
# Close to a normal distribution

# %% [markdown]
# e) Generate 1,000 random samples of size 50 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_50`.

# %%
norm_samples_50 =[]
for x in range(0,1000):
    g = sum(np.random.choice(population, 50, False)) / 50
    norm_samples_50.append(g)
    
norm_samples_5[0:4]
# Out:
# [607.1068971463092, 422.65327219722246, 501.39356797427234, 461.14385511803476]

# %% [markdown]
# f) Plot `norm_samples_50` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(norm_samples_50, kde = True)

# %% [markdown]
# g) How would you describe the shape of the distribution from f), relative to the distribution you generated for part c)?

# %% [markdown]
# The graph with more samples runs closer to the trend line

# %% [markdown]
# h) Run this command:
#
# ```python
# random.seed(46)
# population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]
#
# ```

# %%
import random
random.seed(46)
population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]
sns.distplot(population_2, kde = True)

# %% [markdown]
# i) What is the command in h) doing?

# %% [markdown]
# It randomly samples between 2-10 occurences within a random expoential of 5. for 10000 samples

# %% [markdown]
# j) Is the population created in `population_2` Normally distributed? How do you know?

# %% [markdown]
# No because it does not follow a bell curve shape

# %% [markdown]
# k) Generate 1,000 random samples of size 5 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_5`.

# %%
poiexp_samples_5 = []
for x in range(0, 1000):
    r = sum(np.random.choice(population_2, 5, False))/5 
    poiexp_samples_5.append(r)

poiexp_samples_5
# Out:
# [6.287821905105641,
#  4.678684130265242,
#  3.570005081995403,
#  8.150248919433276,
#  4.4,
#  6.928076683775444,
#  5.8,
#  7.5256894042097375,
#  8.739790829477531,
#  6.657755569898711,
#  4.547292522165395,
#  1.9519193929874497,
#  5.156203988927636,
#  4.351538299540349,
#  3.163081875817091,
#  7.709472134874001,
#  7.563357858397279,
#  8.079235892546137,
#  11.499531784471369,
#  4.845037001006832,
#  3.325873979984634,
#  5.292341699115053,
#  2.342076232618415,
#  4.495379861568405,
#  4.153243616877825,
#  7.501917245559855,
#  7.405714481193646,
#  7.418829419982283,
#  4.2917118307922495,
#  5.594571851914688,
#  2.431814938116509,
#  2.6209286352432337,
#  7.8,
#  4.088487820757313,
#  6.1010881678116275,
#  4.273042950074139,
#  5.060504706652155,
#  3.8536156093492266,
#  4.6,
#  3.4406405058533394,
#  4.340950444577034,
#  8.327547074094193,
#  3.8061833234972533,
#  4.259643314564364,
#  0.9473594119752541,
#  5.899690031228388,
#  5.288564057219624,
#  7.8,
#  7.4,
#  1.6870948418185798,
#  4.3136859932049685,
#  5.0,
#  5.4,
#  6.523782296207273,
#  4.092931748601929,
#  4.907388665083257,
#  6.4,
#  5.557117667379192,
#  8.776589973868806,
#  7.180015926482251,
#  6.316689963704901,
#  8.585763056587007,
#  6.130841185007418,
#  4.0373883816826766,
#  6.4,
#  5.671227138967995,
#  8.222419635154967,
#  4.307252227982557,
#  8.827968883187898,
#  8.535632154122181,
#  3.4455123866062225,
#  5.4615578066832295,
#  6.92476346620914,
#  6.0,
#  7.369508698678206,
#  6.793372606839846,
#  2.1447574828883527,
#  5.873702921728805,
#  5.894772412268731,
#  10.200564220380947,
#  2.73406157697436,
#  5.8,
#  7.8,
#  6.004246828284751,
#  5.880330171915669,
#  3.698086497669962,
#  8.53948382694318,
#  6.2,
#  10.260074611066575,
#  4.986465112076129,
#  3.6786186381055686,
#  4.462322649696808,
#  4.090880926208187,
#  6.939979309243597,
#  4.806173476160811,
#  7.080021686501586,
#  6.397306517472339,
#  5.792458432006641,
#  2.2,
#  6.468422302645398,
#  4.782775924267806,
#  6.8,
#  5.600445264933607,
#  8.966080717552941,
#  10.99102553173614,
#  6.313915810530423,
#  4.229386900173192,
#  7.224593268688855,
#  10.8,
#  5.7074701853400915,
#  10.93988227384842,
#  4.284311581839576]

# %% [markdown]
# l) Plot `poiexp_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(poiexp_samples_5, kde=True)

# %% [markdown]
# m) How would you describe the shape of the distribution from l)?

# %% [markdown]
# Closer to a normal distribution

# %% [markdown]
# n) Generate 1,000 random samples of size 50 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_50`.

# %%
poiexp_samples_50 = []
for x in range(0, 1000):
    r = sum(np.random.choice(population_2, 50, False))/50 
    poiexp_samples_50.append(r)

poiexp_samples_50
# Out:
# [5.272492011404255,
#  5.37250077304503,
#  6.685020718050408,
#  4.330100829853949,
#  5.603691664198335,
#  6.067880806983757,
#  5.702080592471328,
#  5.273993523335719,
#  6.058207815099417,
#  5.3275918153488115,
#  6.167969604130754,
#  6.4953661710549575,
#  6.131794767831423,
#  6.441170244941589,
#  6.363706437319042,
#  5.594557669134702,
#  6.024629978391554,
#  5.93765689501091,
#  4.47374284389549,
#  5.910092959590716,
#  5.872446327118126,
#  6.580906087653376,
#  6.0031391422573765,
#  5.385431893950827,
#  5.669648283896965,
#  5.166521431590216,
#  5.1562376111786765,
#  5.924318263056571,
#  6.043484903224939,
#  6.270107494971508,
#  5.3969167146496275,
#  5.200188141877846,
#  5.416511423780134,
#  6.107584461052031,
#  5.4499971372413665,
#  5.7194473688127765,
#  4.368342184837336,
#  6.388429308360044,
#  6.14815592828072,
#  4.522199157863514,
#  5.5250734893618825,
#  5.263437542030149,
#  4.2836878017710855,
#  4.401412314402405,
#  6.278613082173106,
#  5.6376276284017885,
#  6.902554413510573,
#  5.7703137304719245,
#  5.110708725095142,
#  5.420564132441016,
#  6.046509820119224,
#  4.998131057347961,
#  5.780744558975321,
#  5.24335846176007,
#  5.0428437918666615,
#  5.039920742278282,
#  6.243844136336673,
#  5.936578869084568,
#  4.02121222069116,
#  6.786651660316403,
#  5.927515950397642,
#  5.778383415538732,
#  5.905545659819717,
#  4.642343869305924,
#  6.230731549635766,
#  5.345663227642826,
#  5.213850959381881,
#  5.7384672600326745,
#  5.494169560301256,
#  5.610524804262022,
#  5.161534419366072,
#  5.019648575430049,
#  5.903361377184861,
#  6.28238612103313,
#  3.604790568388941,
#  5.0304310929302725,
#  4.6120511553898,
#  5.73379440290455,
#  6.33422057670203,
#  5.348617364613481,
#  6.896718106208267,
#  5.689444320946745,
#  6.867773448407944,
#  6.190732561150022,
#  5.910798199502307,
#  4.673734596715722,
#  5.63585505063789,
#  7.6140384379478565,
#  5.935562207587884,
#  6.44837048972147,
#  5.001471594609276,
#  5.834792453135355,
#  5.589098098486488,
#  6.148245762576495,
#  5.961616331731273,
#  5.738838793072029,
#  4.314861179414173,
#  6.28127489262678,
#  4.188007289739478,
#  4.993743523896186,
#  5.376868869742648,
#  6.286948004720722,
#  6.249335383963279,
#  5.395723450560007,
#  5.986240924973715,
#  6.18471670885682,
#  6.99784820444128,
#  4.745764841748328,
#  5.733353581353141,
#  6.710313736617012,
#  6.723497157520311,
#  4.604846628258011,
#  5.403985801448809,
#  5.557499797187453,
#  4.644699652703528,
#  6.201815864046825,
#  6.868129097071906,
#  5.009639384644674,
#  6.657395817355198,
#  5.443360155030195,
#  7.1256547868832225,
#  5.504615493247636,
#  6.43366306163516,
#  5.851323352060953,
#  5.5588356791056865,
#  4.910339642538711,
#  6.498062679741203,
#  5.417547441791613,
#  5.733438078960262,
#  6.336341605649077,
#  4.933260745764003,
#  6.278303678215253,
#  4.636343926092913,
#  5.49684962951845,
#  5.745667878881393,
#  5.674507604399054,
#  6.940480344366018,
#  5.696253103381369,
#  5.55293637534817,
#  5.267033849668298,
#  5.1525188547204674,
#  4.802018835613669,
#  4.962300293360614,
#  5.723838926302729,
#  6.753145129168087,
#  6.30025785770439,
#  6.33661327155774,
#  6.295554436184737,
#  6.591602555531773,
#  5.59950112425925,
#  4.902817159625659,
#  6.103492550396035]

# %% [markdown]
# o) Plot `poiexp_samples_50` with a kernel density estimate using seaborn.distplot.

# %%
sns.distplot(poiexp_samples_50, kde=True)

# %% [markdown]
# p) How would you describe the shape of the distribution from o)?

# %% [markdown]
# More close to a normal distribution

# %% [markdown]
# **You just observed the Central Limit Theorem. Let's make this a bit more explicit.**
#
# q) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`norm_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# A normal distribution

# %% [markdown]
# r) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`norm_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# Closer to a more averaged out normal distribution

# %% [markdown]
# s) So, if our original population is a Normal distribution, what will the sampling distribution be shaped like - regardless of sample size?

# %% [markdown]
# Bell curve

# %% [markdown]
# t) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`poiexp_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# Shaped with a huge hump and another small one.

# %% [markdown]
# u) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`poiexp_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# Much closer to a normal distribution

# %% [markdown]
# v) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is small (like 5)?

# %% [markdown]
# several waves

# %% [markdown]
# w) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is large (like 50)?

# %% [markdown]
# closer to a normal distrubtion with a normal bell curve

# %% [markdown]
# x) When you sample from a non-Normal distribution, what happens to our sampling distribution of $\bar{X}$ as we increase $n$?

# %% [markdown]
# It becomes closer to a normal distribution

# %% [markdown]
# BONUS: If you're so inclined, repeat steps k and l for sample size $n=10, 20, 30, 50, 100$ to look at this phenomenon more closely! You could write a loop to do this.
